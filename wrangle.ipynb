# %%
import os
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import StructType, StructField, StringType
import pandas as pd

# %% [markdown]
# This exercises use the cases, dept, and source tables from the 311_data on the Codeup MySQL server.
#
# - Read the case, department, and source data into their own spark dataframes.
#
# - Let's see how writing to the local disk works in spark:
#
#     - Write the code necessary to store the source data in both csv and json format, store these as sources_csv and sources_json
#     - Inspect your folder structure. What do you notice?
#     Comma seperated and json organizes it into a dictionary format/
#
# - Inspect the data in your dataframes. Are the data types appropriate? Write the code necessary to cast the values to the appropriate types.

# %%
# Generate spark object to initialize a local Spark JVM process
spark = SparkSession.builder.getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/07/05 12:50:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/07/05 12:50:46 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 23/07/05 12:50:46 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 23/07/05 12:50:46 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.

# %%
# source df
source_df = spark.read.csv("source.csv", sep=",", header=True, inferSchema=True)

# cases df
case_df = spark.read.csv("case.csv", sep=",", header=True, inferSchema=True)

# dept df
dept_df = spark.read.csv("dept.csv", sep=",", header=True, inferSchema=True)

# %%
# source df
source_df.write.json("source_json", mode="overwrite")
source_df.write.csv("source_csv", mode="overwrite")

# %%
# case df
case_df.write.json("case_json", mode="overwrite")
case_df.write.csv("case_csv", mode="overwrite")

# %%
# dept df
dept_df.write.json("dept_dept", mode="overwrite")
dept_df.write.csv("dept_csv", mode="overwrite")

# %%
dept_df.dtypes
# Out:
# [('dept_division', 'string'),
#  ('dept_name', 'string'),
#  ('standardized_dept_name', 'string'),
#  ('dept_subject_to_SLA', 'string')]

# %%
case_df.dtypes
# Out:
# [('case_id', 'int'),
#  ('case_opened_date', 'string'),
#  ('case_closed_date', 'string'),
#  ('SLA_due_date', 'string'),
#  ('case_late', 'string'),
#  ('num_days_late', 'double'),
#  ('case_closed', 'string'),
#  ('dept_division', 'string'),
#  ('service_request_type', 'string'),
#  ('SLA_days', 'double'),
#  ('case_status', 'string'),
#  ('source_id', 'string'),
#  ('request_address', 'string'),
#  ('council_district', 'string')]

# %%
# rename columns
case_df = case_df.withColumnRenamed("SLA_due_date", "case_due_date")

# %%
case_df.select("case_opened_date").show(5)
# Out:
# +-------------------+
# |   case_opened_date|
# +-------------------+
# |2018-01-01 00:42:00|
# |2018-01-01 00:46:00|
# |2018-01-01 00:48:00|
# |2018-01-01 01:29:00|
# |2018-01-01 01:34:00|
# +-------------------+
# only showing top 5 rows

# %%
case_df = case_df.withColumn("case_closed", expr('case_closed == "YES"')).withColumn(
    "case_late", expr('case_late == "YES"'))

#Select just the two columns
case_df.select("case_closed", "case_late").show(5)
# Out:
# +-----------+---------+
# |case_closed|case_late|
# +-----------+---------+
# |       true|    false|
# |       true|    false|
# |       true|    false|
# |       true|    false|
# |       true|     true|
# +-----------+---------+
# only showing top 5 rows

# %%
case_df.dtypes
# Out:
# [('case_id', 'int'),
#  ('case_opened_date', 'timestamp'),
#  ('case_closed_date', 'timestamp'),
#  ('case_due_date', 'timestamp'),
#  ('case_late', 'boolean'),
#  ('num_days_late', 'double'),
#  ('case_closed', 'boolean'),
#  ('dept_division', 'string'),
#  ('service_request_type', 'string'),
#  ('SLA_days', 'double'),
#  ('case_status', 'string'),
#  ('source_id', 'string'),
#  ('request_address', 'string'),
#  ('council_district', 'string')]

# %%
#Before
case_df.select('case_opened_date', 'case_closed_date', 'case_due_date').show()
# Out:
# +-------------------+-------------------+-------------+
# |   case_opened_date|   case_closed_date|case_due_date|
# +-------------------+-------------------+-------------+
# |2018-01-01 00:42:00|2018-01-01 12:29:00| 9/26/20 0:42|
# |2018-01-01 00:46:00|2018-01-03 08:11:00|  1/5/18 8:30|
# |2018-01-01 00:48:00|2018-01-02 07:57:00|  1/5/18 8:30|
# |2018-01-01 01:29:00|2018-01-02 08:13:00| 1/17/18 8:30|
# |2018-01-01 01:34:00|2018-01-01 13:29:00|  1/1/18 4:34|
# |2018-01-01 06:28:00|2018-01-01 14:38:00| 1/31/18 8:30|
# |2018-01-01 06:57:00|2018-01-02 15:32:00| 1/17/18 8:30|
# |2018-01-01 06:58:00|2018-01-02 15:32:00| 1/17/18 8:30|
# |2018-01-01 06:58:00|2018-01-02 15:32:00| 1/17/18 8:30|
# |2018-01-01 06:59:00|2018-01-02 15:32:00| 1/17/18 8:30|
# |2018-01-01 07:00:00|2018-01-02 15:32:00| 1/17/18 8:30|
# |2018-01-01 07:02:00|2018-01-02 15:32:00| 1/17/18 8:30|
# |2018-01-01 07:02:00|2018-01-02 15:33:00| 1/17/18 8:30|
# |2018-01-01 07:03:00|2018-01-02 15:32:00| 1/17/18 8:30|
# |2018-01-01 07:04:00|2018-01-02 15:33:00| 1/17/18 8:30|
# |2018-01-01 07:04:00|2018-01-02 15:33:00| 1/17/18 8:30|
# |2018-01-01 07:05:00|2018-01-02 15:33:00| 1/17/18 8:30|
# |2018-01-01 07:06:00|2018-01-02 15:33:00| 1/17/18 8:30|
# |2018-01-01 07:06:00|2018-01-02 15:33:00| 1/17/18 8:30|
# |2018-01-01 07:07:00|2018-01-02 15:33:00| 1/17/18 8:30|
# +-------------------+-------------------+-------------+
# only showing top 20 rows

# %%
fmt = "M/d/yy H:mm"

case_df = (
    case_df.withColumn("case_opened_date", to_timestamp("case_opened_date", fmt))
    .withColumn("case_closed_date", to_timestamp("case_closed_date", fmt))
    .withColumn("case_due_date", to_timestamp("case_due_date", fmt))

)

case_df.select("case_opened_date", "case_closed_date", "case_due_date").show(5)
# Out:
# +-------------------+-------------------+-------------------+
# |   case_opened_date|   case_closed_date|      case_due_date|
# +-------------------+-------------------+-------------------+
# |2018-01-01 00:42:00|2018-01-01 12:29:00|2020-09-26 00:42:00|
# |2018-01-01 00:46:00|2018-01-03 08:11:00|2018-01-05 08:30:00|
# |2018-01-01 00:48:00|2018-01-02 07:57:00|2018-01-05 08:30:00|
# |2018-01-01 01:29:00|2018-01-02 08:13:00|2018-01-17 08:30:00|
# |2018-01-01 01:34:00|2018-01-01 13:29:00|2018-01-01 04:34:00|
# +-------------------+-------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# How old is the latest (in terms of days past SLA) currently open issue? How long has the oldest (in terms of days since opened) currently opened issue been open?

# %%
case_df.sort('case_opened_date', ascending=False).show(1, vertical=True)

# 2018-08-08 - 14.0 days
# Out:
# [Stage 59:=======>                                                  (1 + 7) / 8]
# -RECORD 0------------------------------------
#  case_id              | 1014759619
#  case_opened_date     | 2018-08-08 10:38:00
#  case_closed_date     | null
#  case_due_date        | 2018-08-22 10:38:00
#  case_late            | false
#  num_days_late        | -13.44305556
#  case_closed          | false
#  dept_division        | Code Enforcement
#  service_request_type | Bandit Signs
#  SLA_days             | 14.0
#  case_status          | Open
#  source_id            | CRM_Listener
#  request_address      | 1935  MILITARY DR...
#  council_district     | 3
#  num_weeks_late       | -1.9204365085714286
# only showing top 1 row

# %%
# mask of only open cases
cse_df2 = case_df.filter(case_df.case_closed == "False")

# %%
# min and max dates
cse_df2.select(
    min(cse_df2.case_opened_date), max(cse_df2.case_opened_date)
).show()
# Out:
# +---------------------+---------------------+
# |min(case_opened_date)|max(case_opened_date)|
# +---------------------+---------------------+
# |  2017-01-01 13:48:00|  2018-08-08 10:38:00|
# +---------------------+---------------------+

# %% [markdown]
# 2. How many Stray Animal cases are there?

# %%
case_df.count()
# Out:
# 841704

# %% [markdown]
# 3. How many service requests that are assigned to the Field Operations department (dept_division) are not classified as "Officer Standby" request type (service_request_type)? 3013

# %%
case_df.filter(case_df.dept_division == "Field Operations").where(case_df.service_request_type == "Officer Standby").count()
# Out:
# [Stage 105:============================>                            (4 + 4) / 8]
# 3013

# %% [markdown]
# 4. Convert the council_district column to a string column.

# %%
# cast to appropriate dtype - council district
case_df = case_df.withColumn("council_district", col("council_district").cast("string"))

# %% [markdown]
# 5. Extract the year from the case_closed_date column.

# %%
case_df.withColumn(
    "year",
    year("case_closed_date")
).show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  case_id              | 1014127332
#  case_opened_date     | 2018-01-01 00:42:00
#  case_closed_date     | 2018-01-01 12:29:00
#  case_due_date        | 2020-09-26 00:42:00
#  case_late            | false
#  num_days_late        | -998.5087616000001
#  case_closed          | true
#  dept_division        | Field Operations
#  service_request_type | Stray Animal
#  SLA_days             | 999.0
#  case_status          | Closed
#  source_id            | svcCRMLS
#  request_address      | 2315  EL PASO ST,...
#  council_district     | 5
#  num_weeks_late       | -142.6441088
#  year                 | 2018
# -RECORD 1------------------------------------
#  case_id              | 1014127333
#  case_opened_date     | 2018-01-01 00:46:00
#  case_closed_date     | 2018-01-03 08:11:00
#  case_due_date        | 2018-01-05 08:30:00
#  case_late            | false
#  num_days_late        | -2.0126041669999997
#  case_closed          | true
#  dept_division        | Storm Water
#  service_request_type | Removal Of Obstru...
#  SLA_days             | 4.322222222
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 2215  GOLIAD RD, ...
#  council_district     | 3
#  num_weeks_late       | -0.28751488099999994
#  year                 | 2018
# -RECORD 2------------------------------------
#  case_id              | 1014127334
#  case_opened_date     | 2018-01-01 00:48:00
#  case_closed_date     | 2018-01-02 07:57:00
#  case_due_date        | 2018-01-05 08:30:00
#  case_late            | false
#  num_days_late        | -3.022337963
#  case_closed          | true
#  dept_division        | Storm Water
#  service_request_type | Removal Of Obstru...
#  SLA_days             | 4.320729167
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 102  PALFREY ST W...
#  council_district     | 3
#  num_weeks_late       | -0.43176256614285713
#  year                 | 2018
# -RECORD 3------------------------------------
#  case_id              | 1014127335
#  case_opened_date     | 2018-01-01 01:29:00
#  case_closed_date     | 2018-01-02 08:13:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -15.01148148
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.29188657
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 114  LA GARDE ST,...
#  council_district     | 3
#  num_weeks_late       | -2.1444973542857144
#  year                 | 2018
# -RECORD 4------------------------------------
#  case_id              | 1014127336
#  case_opened_date     | 2018-01-01 01:34:00
#  case_closed_date     | 2018-01-01 13:29:00
#  case_due_date        | 2018-01-01 04:34:00
#  case_late            | true
#  num_days_late        | 0.37216435200000003
#  case_closed          | true
#  dept_division        | Field Operations
#  service_request_type | Animal Cruelty(Cr...
#  SLA_days             | 0.125
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 734  CLEARVIEW DR...
#  council_district     | 7
#  num_weeks_late       | 0.053166336
#  year                 | 2018
# -RECORD 5------------------------------------
#  case_id              | 1014127337
#  case_opened_date     | 2018-01-01 06:28:00
#  case_closed_date     | 2018-01-01 14:38:00
#  case_due_date        | 2018-01-31 08:30:00
#  case_late            | false
#  num_days_late        | -29.74398148
#  case_closed          | true
#  dept_division        | Signals
#  service_request_type | Traffic Signal Op...
#  SLA_days             | 30.08446759
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | BANDERA RD and BR...
#  council_district     | 7
#  num_weeks_late       | -4.249140211428571
#  year                 | 2018
# -RECORD 6------------------------------------
#  case_id              | 1014127338
#  case_opened_date     | 2018-01-01 06:57:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70673611
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06429398
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.1009623014285714
#  year                 | 2018
# -RECORD 7------------------------------------
#  case_id              | 1014127339
#  case_opened_date     | 2018-01-01 06:58:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70662037
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.063796300000003
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.100945767142857
#  year                 | 2018
# -RECORD 8------------------------------------
#  case_id              | 1014127340
#  case_opened_date     | 2018-01-01 06:58:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70662037
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.06333333
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.100945767142857
#  year                 | 2018
# -RECORD 9------------------------------------
#  case_id              | 1014127341
#  case_opened_date     | 2018-01-01 06:59:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70649306
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.0628588
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.10092758
#  year                 | 2018
# -RECORD 10-----------------------------------
#  case_id              | 1014127342
#  case_opened_date     | 2018-01-01 07:00:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70649306
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06237269
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.10092758
#  year                 | 2018
# -RECORD 11-----------------------------------
#  case_id              | 1014127343
#  case_opened_date     | 2018-01-01 07:02:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70636574
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.06104167
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.1009093914285715
#  year                 | 2018
# -RECORD 12-----------------------------------
#  case_id              | 1014127344
#  case_opened_date     | 2018-01-01 07:02:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70625
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06059028
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 4
#  num_weeks_late       | -2.100892857142857
#  year                 | 2018
# -RECORD 13-----------------------------------
#  case_id              | 1014127345
#  case_opened_date     | 2018-01-01 07:03:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70636574
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06011574
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 4
#  num_weeks_late       | -2.1009093914285715
#  year                 | 2018
# -RECORD 14-----------------------------------
#  case_id              | 1014127346
#  case_opened_date     | 2018-01-01 07:04:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70623843
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.05953704
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 4
#  num_weeks_late       | -2.1008912042857144
#  year                 | 2018
# -RECORD 15-----------------------------------
#  case_id              | 1014127347
#  case_opened_date     | 2018-01-01 07:04:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.705891199999998
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05907407
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.1008416
#  year                 | 2018
# -RECORD 16-----------------------------------
#  case_id              | 1014127348
#  case_opened_date     | 2018-01-01 07:05:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70600694
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05864583
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.100858134285714
#  year                 | 2018
# -RECORD 17-----------------------------------
#  case_id              | 1014127349
#  case_opened_date     | 2018-01-01 07:06:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70576389
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.05819444
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.100823412857143
#  year                 | 2018
# -RECORD 18-----------------------------------
#  case_id              | 1014127350
#  case_opened_date     | 2018-01-01 07:06:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70576389
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05775463
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.100823412857143
#  year                 | 2018
# -RECORD 19-----------------------------------
#  case_id              | 1014127351
#  case_opened_date     | 2018-01-01 07:07:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70564815
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05733796
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.1008068785714284
#  year                 | 2018
# only showing top 20 rows

# %% [markdown]
# 6. Convert num_days_late from days to hours in new columns num_hours_late.

# %%
case_df.withColumn(
    "num_hours_late",
    round(case_df.num_days_late) * -24).show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  case_id              | 1014127332
#  case_opened_date     | 2018-01-01 00:42:00
#  case_closed_date     | 2018-01-01 12:29:00
#  case_due_date        | 2020-09-26 00:42:00
#  case_late            | false
#  num_days_late        | -998.5087616000001
#  case_closed          | true
#  dept_division        | Field Operations
#  service_request_type | Stray Animal
#  SLA_days             | 999.0
#  case_status          | Closed
#  source_id            | svcCRMLS
#  request_address      | 2315  EL PASO ST,...
#  council_district     | 5
#  num_weeks_late       | -142.6441088
#  num_hours_late       | 23976.0
# -RECORD 1------------------------------------
#  case_id              | 1014127333
#  case_opened_date     | 2018-01-01 00:46:00
#  case_closed_date     | 2018-01-03 08:11:00
#  case_due_date        | 2018-01-05 08:30:00
#  case_late            | false
#  num_days_late        | -2.0126041669999997
#  case_closed          | true
#  dept_division        | Storm Water
#  service_request_type | Removal Of Obstru...
#  SLA_days             | 4.322222222
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 2215  GOLIAD RD, ...
#  council_district     | 3
#  num_weeks_late       | -0.28751488099999994
#  num_hours_late       | 48.0
# -RECORD 2------------------------------------
#  case_id              | 1014127334
#  case_opened_date     | 2018-01-01 00:48:00
#  case_closed_date     | 2018-01-02 07:57:00
#  case_due_date        | 2018-01-05 08:30:00
#  case_late            | false
#  num_days_late        | -3.022337963
#  case_closed          | true
#  dept_division        | Storm Water
#  service_request_type | Removal Of Obstru...
#  SLA_days             | 4.320729167
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 102  PALFREY ST W...
#  council_district     | 3
#  num_weeks_late       | -0.43176256614285713
#  num_hours_late       | 72.0
# -RECORD 3------------------------------------
#  case_id              | 1014127335
#  case_opened_date     | 2018-01-01 01:29:00
#  case_closed_date     | 2018-01-02 08:13:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -15.01148148
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.29188657
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 114  LA GARDE ST,...
#  council_district     | 3
#  num_weeks_late       | -2.1444973542857144
#  num_hours_late       | 360.0
# -RECORD 4------------------------------------
#  case_id              | 1014127336
#  case_opened_date     | 2018-01-01 01:34:00
#  case_closed_date     | 2018-01-01 13:29:00
#  case_due_date        | 2018-01-01 04:34:00
#  case_late            | true
#  num_days_late        | 0.37216435200000003
#  case_closed          | true
#  dept_division        | Field Operations
#  service_request_type | Animal Cruelty(Cr...
#  SLA_days             | 0.125
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 734  CLEARVIEW DR...
#  council_district     | 7
#  num_weeks_late       | 0.053166336
#  num_hours_late       | -0.0
# -RECORD 5------------------------------------
#  case_id              | 1014127337
#  case_opened_date     | 2018-01-01 06:28:00
#  case_closed_date     | 2018-01-01 14:38:00
#  case_due_date        | 2018-01-31 08:30:00
#  case_late            | false
#  num_days_late        | -29.74398148
#  case_closed          | true
#  dept_division        | Signals
#  service_request_type | Traffic Signal Op...
#  SLA_days             | 30.08446759
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | BANDERA RD and BR...
#  council_district     | 7
#  num_weeks_late       | -4.249140211428571
#  num_hours_late       | 720.0
# -RECORD 6------------------------------------
#  case_id              | 1014127338
#  case_opened_date     | 2018-01-01 06:57:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70673611
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06429398
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.1009623014285714
#  num_hours_late       | 360.0
# -RECORD 7------------------------------------
#  case_id              | 1014127339
#  case_opened_date     | 2018-01-01 06:58:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70662037
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.063796300000003
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.100945767142857
#  num_hours_late       | 360.0
# -RECORD 8------------------------------------
#  case_id              | 1014127340
#  case_opened_date     | 2018-01-01 06:58:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70662037
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.06333333
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.100945767142857
#  num_hours_late       | 360.0
# -RECORD 9------------------------------------
#  case_id              | 1014127341
#  case_opened_date     | 2018-01-01 06:59:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70649306
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.0628588
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.10092758
#  num_hours_late       | 360.0
# -RECORD 10-----------------------------------
#  case_id              | 1014127342
#  case_opened_date     | 2018-01-01 07:00:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70649306
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06237269
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.10092758
#  num_hours_late       | 360.0
# -RECORD 11-----------------------------------
#  case_id              | 1014127343
#  case_opened_date     | 2018-01-01 07:02:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70636574
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.06104167
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10133  FIGARO CAN...
#  council_district     | 4
#  num_weeks_late       | -2.1009093914285715
#  num_hours_late       | 360.0
# -RECORD 12-----------------------------------
#  case_id              | 1014127344
#  case_opened_date     | 2018-01-01 07:02:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70625
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06059028
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 4
#  num_weeks_late       | -2.100892857142857
#  num_hours_late       | 360.0
# -RECORD 13-----------------------------------
#  case_id              | 1014127345
#  case_opened_date     | 2018-01-01 07:03:00
#  case_closed_date     | 2018-01-02 15:32:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70636574
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.06011574
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 4
#  num_weeks_late       | -2.1009093914285715
#  num_hours_late       | 360.0
# -RECORD 14-----------------------------------
#  case_id              | 1014127346
#  case_opened_date     | 2018-01-01 07:04:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70623843
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.05953704
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 10129  BOXING PAS...
#  council_district     | 4
#  num_weeks_late       | -2.1008912042857144
#  num_hours_late       | 360.0
# -RECORD 15-----------------------------------
#  case_id              | 1014127347
#  case_opened_date     | 2018-01-01 07:04:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.705891199999998
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05907407
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.1008416
#  num_hours_late       | 360.0
# -RECORD 16-----------------------------------
#  case_id              | 1014127348
#  case_opened_date     | 2018-01-01 07:05:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70600694
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05864583
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.100858134285714
#  num_hours_late       | 360.0
# -RECORD 17-----------------------------------
#  case_id              | 1014127349
#  case_opened_date     | 2018-01-01 07:06:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70576389
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Right Of Way/Side...
#  SLA_days             | 16.05819444
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.100823412857143
#  num_hours_late       | 360.0
# -RECORD 18-----------------------------------
#  case_id              | 1014127350
#  case_opened_date     | 2018-01-01 07:06:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70576389
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05775463
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.100823412857143
#  num_hours_late       | 360.0
# -RECORD 19-----------------------------------
#  case_id              | 1014127351
#  case_opened_date     | 2018-01-01 07:07:00
#  case_closed_date     | 2018-01-02 15:33:00
#  case_due_date        | 2018-01-17 08:30:00
#  case_late            | false
#  num_days_late        | -14.70564815
#  case_closed          | true
#  dept_division        | Code Enforcement
#  service_request_type | Front Or Side Yar...
#  SLA_days             | 16.05733796
#  case_status          | Closed
#  source_id            | svcCRMSS
#  request_address      | 834  BARREL POINT...
#  council_district     | 4
#  num_weeks_late       | -2.1008068785714284
#  num_hours_late       | 360.0
# only showing top 20 rows

# %% [markdown]
# 7. Join the case data with the source and department data.

# %%
# join case and dept
df = (
    case_df
    # left join on dept_division
    .join(dept_df, "dept_division", "left")
    # drop all the columns except for standardized name, as it has much fewer unique values
    .drop(dept_df.dept_division)
    .drop(dept_df.dept_name)
    .drop(case_df.dept_division)
    .withColumnRenamed("standarized_dept_name", "department")
    # convert last col to a boolean
    .withColumn("dept_subject_to_SLA", col("dept_subject_to_SLA")=="YES")
)

df.show(2, vertical=True)
# Out:
# -RECORD 0--------------------------------------
#  case_id                | 1014127332
#  case_opened_date       | 2018-01-01 00:42:00
#  case_closed_date       | 2018-01-01 12:29:00
#  case_due_date          | 2020-09-26 00:42:00
#  case_late              | false
#  num_days_late          | -998.5087616000001
#  case_closed            | true
#  service_request_type   | Stray Animal
#  SLA_days               | 999.0
#  case_status            | Closed
#  source_id              | svcCRMLS
#  request_address        | 2315  EL PASO ST,...
#  council_district       | 5
#  num_weeks_late         | -142.6441088
#  standardized_dept_name | Animal Care Services
#  dept_subject_to_SLA    | true
# -RECORD 1--------------------------------------
#  case_id                | 1014127333
#  case_opened_date       | 2018-01-01 00:46:00
#  case_closed_date       | 2018-01-03 08:11:00
#  case_due_date          | 2018-01-05 08:30:00
#  case_late              | false
#  num_days_late          | -2.0126041669999997
#  case_closed            | true
#  service_request_type   | Removal Of Obstru...
#  SLA_days               | 4.322222222
#  case_status            | Closed
#  source_id              | svcCRMSS
#  request_address        | 2215  GOLIAD RD, ...
#  council_district       | 3
#  num_weeks_late         | -0.28751488099999994
#  standardized_dept_name | Trans & Cap Impro...
#  dept_subject_to_SLA    | true
# only showing top 2 rows

# %%
# join df and source
df = (
    df
    # left join on dept_division
    .join(source_df, "source_id", "right")
    # drop all the columns except for standardized name, as it has much fewer unique values
    .drop(source_df.source_id)
    .drop(df.source_id)
    .withColumnRenamed("source_username", "username")
)

df.show( vertical=True)
# Out:
# [Stage 164:=======>                                                 (1 + 7) / 8]
# -RECORD 0--------------------------------------
#  case_id                | 1014128056
#  case_opened_date       | 2018-01-02 08:21:00
#  case_closed_date       | 2018-01-10 08:39:00
#  case_due_date          | 2018-01-05 08:30:00
#  case_late              | true
#  num_days_late          | 5.00681713
#  case_closed            | true
#  service_request_type   | Solid Waste Fees ...
#  SLA_days               | 3.00619213
#  case_status            | Closed
#  request_address        | 3214  STONEY FORK...
#  council_district       | 10
#  num_weeks_late         | 0.71525959
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 1--------------------------------------
#  case_id                | 1014128366
#  case_opened_date       | 2018-01-02 09:36:00
#  case_closed_date       | 2018-01-03 13:28:00
#  case_due_date          | 2018-01-09 09:36:00
#  case_late              | false
#  num_days_late          | -5.838321758999999
#  case_closed            | true
#  service_request_type   | Cart Exchange Req...
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 11822  SONG, San ...
#  council_district       | 9
#  num_weeks_late         | -0.8340459655714285
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 2--------------------------------------
#  case_id                | 1014128555
#  case_opened_date       | 2018-01-02 10:07:00
#  case_closed_date       | 2018-01-03 15:29:00
#  case_due_date          | 2018-01-05 10:07:00
#  case_late              | false
#  num_days_late          | -1.7764930559999998
#  case_closed            | true
#  service_request_type   | No Pickup
#  SLA_days               | 3.0
#  case_status            | Closed
#  request_address        | 13703  BLUFF ROCK...
#  council_district       | 9
#  num_weeks_late         | -0.25378472228571425
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 3--------------------------------------
#  case_id                | 1014128764
#  case_opened_date       | 2018-01-02 10:45:00
#  case_closed_date       | 2018-01-08 13:58:00
#  case_due_date          | 2018-01-09 10:45:00
#  case_late              | false
#  num_days_late          | -0.865798611
#  case_closed            | true
#  service_request_type   | Cart Exchange Req...
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 6270  RIDGEBROOK,...
#  council_district       | 6
#  num_weeks_late         | -0.12368551585714285
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 4--------------------------------------
#  case_id                | 1014129021
#  case_opened_date       | 2018-01-02 11:26:00
#  case_closed_date       | 2018-01-03 14:08:00
#  case_due_date          | 2018-01-09 11:26:00
#  case_late              | false
#  num_days_late          | -5.887905093
#  case_closed            | true
#  service_request_type   | Cart Exchange Req...
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 135  MAGNOLIA DR,...
#  council_district       | 1
#  num_weeks_late         | -0.841129299
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 5--------------------------------------
#  case_id                | 1014129041
#  case_opened_date       | 2018-01-02 11:27:00
#  case_closed_date       | 2018-01-03 14:07:00
#  case_due_date          | 2018-01-09 11:27:00
#  case_late              | false
#  num_days_late          | -5.88869213
#  case_closed            | true
#  service_request_type   | Cart Exchange Req...
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 135  MAGNOLIA DR,...
#  council_district       | 1
#  num_weeks_late         | -0.8412417328571429
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 6--------------------------------------
#  case_id                | 1014129047
#  case_opened_date       | 2018-01-02 11:27:00
#  case_closed_date       | 2018-01-03 14:07:00
#  case_due_date          | 2018-01-09 11:27:00
#  case_late              | false
#  num_days_late          | -5.889444444
#  case_closed            | true
#  service_request_type   | Cart Delivery
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 135  MAGNOLIA DR,...
#  council_district       | 1
#  num_weeks_late         | -0.8413492062857142
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 7--------------------------------------
#  case_id                | 1014129727
#  case_opened_date       | 2018-01-02 13:13:00
#  case_closed_date       | 2018-01-03 14:07:00
#  case_due_date          | 2018-01-09 13:13:00
#  case_late              | false
#  num_days_late          | -5.963032407
#  case_closed            | true
#  service_request_type   | Cart Delivery
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 207  MULBERRY AVE...
#  council_district       | 1
#  num_weeks_late         | -0.8518617724285714
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 8--------------------------------------
#  case_id                | 1014129828
#  case_opened_date       | 2018-01-02 13:34:00
#  case_closed_date       | 2018-01-04 15:38:00
#  case_due_date          | 2018-01-09 13:34:00
#  case_late              | false
#  num_days_late          | -4.914131944
#  case_closed            | true
#  service_request_type   | Damaged Cart
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 10015  AZTEC VILL...
#  council_district       | 4
#  num_weeks_late         | -0.7020188491428572
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 9--------------------------------------
#  case_id                | 1014129918
#  case_opened_date       | 2018-01-02 13:58:00
#  case_closed_date       | 2018-01-04 13:22:00
#  case_due_date          | 2018-01-09 13:58:00
#  case_late              | false
#  num_days_late          | -5.02525463
#  case_closed            | true
#  service_request_type   | Damaged Cart
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 16111  TREERIDGE ...
#  council_district       | 10
#  num_weeks_late         | -0.7178935185714286
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 10-------------------------------------
#  case_id                | 1014130165
#  case_opened_date       | 2018-01-02 14:46:00
#  case_closed_date       | 2018-01-08 15:43:00
#  case_due_date          | 2018-01-17 14:46:00
#  case_late              | false
#  num_days_late          | -8.960381944
#  case_closed            | true
#  service_request_type   | Additional Garbag...
#  SLA_days               | 15.0
#  case_status            | Closed
#  request_address        | 249  TERRA ALTA E...
#  council_district       | 10
#  num_weeks_late         | -1.2800545634285714
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 11-------------------------------------
#  case_id                | 1014130174
#  case_opened_date       | 2018-01-02 14:47:00
#  case_closed_date       | 2018-01-08 14:10:00
#  case_due_date          | 2018-01-11 14:47:00
#  case_late              | false
#  num_days_late          | -3.0255208330000003
#  case_closed            | true
#  service_request_type   | Additional Cart R...
#  SLA_days               | 9.0
#  case_status            | Closed
#  request_address        | 249  TERRA ALTA E...
#  council_district       | 10
#  num_weeks_late         | -0.4322172618571429
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 12-------------------------------------
#  case_id                | 1014130184
#  case_opened_date       | 2018-01-02 14:49:00
#  case_closed_date       | 2018-01-08 14:10:00
#  case_due_date          | 2018-01-11 14:49:00
#  case_late              | false
#  num_days_late          | -3.0266319439999996
#  case_closed            | true
#  service_request_type   | Additional Cart R...
#  SLA_days               | 9.0
#  case_status            | Closed
#  request_address        | 249  TERRA ALTA E...
#  council_district       | 10
#  num_weeks_late         | -0.43237599199999993
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 13-------------------------------------
#  case_id                | 1014130621
#  case_opened_date       | 2018-01-02 16:17:00
#  case_closed_date       | 2018-01-04 13:38:00
#  case_due_date          | 2018-01-09 16:17:00
#  case_late              | false
#  num_days_late          | -5.110451389
#  case_closed            | true
#  service_request_type   | Lost/Stolen Cart
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 305  CLARK AVE, S...
#  council_district       | 2
#  num_weeks_late         | -0.7300644841428571
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 14-------------------------------------
#  case_id                | 1014131449
#  case_opened_date       | 2018-01-03 08:37:00
#  case_closed_date       | 2018-01-10 16:16:00
#  case_due_date          | 2018-01-12 08:37:00
#  case_late              | false
#  num_days_late          | -1.681134259
#  case_closed            | true
#  service_request_type   | Brush - Out of Cy...
#  SLA_days               | 9.0
#  case_status            | Closed
#  request_address        | 1370  BAYOU DR, S...
#  council_district       | 4
#  num_weeks_late         | -0.240162037
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 15-------------------------------------
#  case_id                | 1014132075
#  case_opened_date       | 2018-01-03 10:56:00
#  case_closed_date       | 2018-01-03 12:28:00
#  case_due_date          | 2018-01-08 10:56:00
#  case_late              | false
#  num_days_late          | -4.93625
#  case_closed            | true
#  service_request_type   | Brush / Bulky Mis...
#  SLA_days               | 5.0
#  case_status            | Closed
#  request_address        | 403  TANGO, San A...
#  council_district       | 9
#  num_weeks_late         | -0.7051785714285714
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 16-------------------------------------
#  case_id                | 1014132094
#  case_opened_date       | 2018-01-03 11:00:00
#  case_closed_date       | 2018-01-03 12:27:00
#  case_due_date          | 2018-01-08 11:00:00
#  case_late              | false
#  num_days_late          | -4.939212963
#  case_closed            | true
#  service_request_type   | Brush / Bulky Mis...
#  SLA_days               | 5.0
#  case_status            | Closed
#  request_address        | 14234  GEORGE RD,...
#  council_district       | 8
#  num_weeks_late         | -0.7056018518571429
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 17-------------------------------------
#  case_id                | 1014132157
#  case_opened_date       | 2018-01-03 11:11:00
#  case_closed_date       | 2018-01-06 14:56:00
#  case_due_date          | 2018-01-10 11:11:00
#  case_late              | false
#  num_days_late          | -3.844409722
#  case_closed            | true
#  service_request_type   | Cart Delivery
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 10322  MISSION RO...
#  council_district       | 4
#  num_weeks_late         | -0.5492013888571429
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 18-------------------------------------
#  case_id                | 1014133662
#  case_opened_date       | 2018-01-03 16:10:00
#  case_closed_date       | 2018-01-10 16:14:00
#  case_due_date          | 2018-01-12 16:10:00
#  case_late              | false
#  num_days_late          | -1.99712963
#  case_closed            | true
#  service_request_type   | Brush - Out of Cy...
#  SLA_days               | 9.0
#  case_status            | Closed
#  request_address        | 232  RENNER DR, S...
#  council_district       | 1
#  num_weeks_late         | -0.28530423285714285
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# -RECORD 19-------------------------------------
#  case_id                | 1014134706
#  case_opened_date       | 2018-01-04 09:47:00
#  case_closed_date       | 2018-01-09 13:04:00
#  case_due_date          | 2018-01-11 09:47:00
#  case_late              | false
#  num_days_late          | -1.863171296
#  case_closed            | true
#  service_request_type   | Lost/Stolen Cart
#  SLA_days               | 7.0
#  case_status            | Closed
#  request_address        | 14963  OAK SUMMIT...
#  council_district       | 10
#  num_weeks_late         | -0.266167328
#  standardized_dept_name | Solid Waste
#  dept_subject_to_SLA    | true
#  username               | Michelle Urrutia
# only showing top 20 rows

# %% [markdown]
# 8. Are there any cases that do not have a request source? No?

# %%
case_df.select(case_df.request_address).orderBy(case_df.request_address.desc_nulls_first()).collect()
# Out:
# [Row(request_address='ZURICH and AMSTERDAM'),
#  Row(request_address='ZULEMA and SW 42ND ST'),
#  Row(request_address='ZULEMA and 41ST ST SW'),
#  Row(request_address='ZULEMA and 41ST ST SW'),
#  Row(request_address='ZULEMA and 41ST ST SW'),
#  Row(request_address='ZULEMA and 41ST ST SW'),
#  Row(request_address='ZULEMA and 41ST ST SW'),
#  Row(request_address='ZULEMA and 41ST ST SW'),
#  Row(request_address='ZULEMA and 41ST ST SW'),
#  Row(request_address='ZEBULON DR and MARY TODD DR'),
#  Row(request_address='ZEBULON DR and MARY TODD DR'),
#  Row(request_address='ZEBULON DR and MARY TODD DR'),
#  Row(request_address='ZEBULON DR and MARY TODD DR'),
#  Row(request_address='ZARZAMORA S and SAN FERNANDO'),
#  Row(request_address='ZARZAMORA S and BARRETT PLACE'),
#  Row(request_address='ZARZAMORA N and TEXAS AVE'),
#  Row(request_address='ZARZAMORA N and MISTLETOE W'),
#  Row(request_address='ZARZAMORA N and COMMERCE ST W'),
#  Row(request_address='ZANGS DR and STEMMONS'),
#  Row(request_address='ZANGS DR and STEMMONS'),
#  Row(request_address='ZANGS DR and JEANIE RILEY'),
#  Row(request_address='ZABRA DR and HORAL DR'),
#  Row(request_address='YUKON BLVD and WALHALLA AVE'),
#  Row(request_address='YUKON BLVD and WALHALLA AVE'),
#  Row(request_address='YUCCA ST and PECAN VALLEY D'),
#  Row(request_address='YUCCA ST and PECAN VALLEY D'),
#  Row(request_address='YUCCA ST and ANITA ST'),
#  Row(request_address='YOUNG AVE E and SIERRA ST'),
#  Row(request_address='YOUNG AVE E and SIERRA ST'),
#  Row(request_address='YOUNG AVE E and SIERRA ST'),
#  Row(request_address='YOUNG AVE E and SIERRA ST'),
#  Row(request_address='YOUNG AVE E and SIERRA ST'),
#  Row(request_address='YORMIS NEST and ESTONIA GREY'),
#  Row(request_address='YORMIS NEST and ESTONIA GREY'),
#  Row(request_address='YOLANDA and PLAINVIEW DR'),
#  Row(request_address='YETT AVE and YUKON BLVD'),
#  Row(request_address='YETT AVE and YUKON BLVD'),
#  Row(request_address='YETT AVE and YUKON BLVD'),
#  Row(request_address='YETT AVE and YUKON BLVD'),
#  Row(request_address='YELLOW STONE and ROOSEVELT AVE'),
#  Row(request_address='YELLOW STONE and ROOSEVELT AVE'),
#  Row(request_address='YELLOW CREEK and LEAFY RIDGE'),
#  Row(request_address='YELLOW CREEK and GABLE POINT'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YELLOW CREEK and ELLISON DR N'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YARROW BLVD and MILITARY DR SW'),
#  Row(request_address='YALE AVE and MERIDIAN AVE'),
#  Row(request_address='YALE AVE and IH 10 W'),
#  Row(request_address='WYOMING ST and DREISS'),
#  Row(request_address='WYOMING ST and DREISS'),
#  Row(request_address='WYNDALE and OAK GLEN'),
#  Row(request_address='WYNDALE and CAVE LANE'),
#  Row(request_address='WYCLIFF and DELLCREST DR'),
#  Row(request_address='WYCLIFF and DELLCREST DR'),
#  Row(request_address='WYCLIFF and DELLCREST DR'),
#  Row(request_address='WYCLIFF and BIBLE ST'),
#  Row(request_address='WYCLIFF RISE and KNIGHTS WOOD'),
#  Row(request_address='WYCLIFF RISE and KNIGHTS WOOD'),
#  Row(request_address='WYANOKE and MEDFORD'),
#  Row(request_address='WYANOKE and HATHAWAY DR W'),
#  Row(request_address='WW WHITE RD S and WINNEWAY'),
#  Row(request_address='WW WHITE RD S and WILDT RD'),
#  Row(request_address='WW WHITE RD S and WILDT RD'),
#  Row(request_address='WW WHITE RD S and UTOPIA LANE'),
#  Row(request_address='WW WHITE RD S and HILDEBRANDT'),
#  Row(request_address='WW WHITE RD S and HEIN N'),
#  Row(request_address='WW WHITE RD S and EB IH 10'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD S and 410 SE'),
#  Row(request_address='WW WHITE RD N and WB IH 10'),
#  Row(request_address='WW WHITE RD N and WB IH 10'),
#  Row(request_address='WW WHITE RD N and WB IH 10'),
#  Row(request_address='WW WHITE RD N and WB IH 10'),
#  Row(request_address='WW WHITE RD N and EMIL'),
#  Row(request_address='WUTHERING HTS and CUL-DE-SAC'),
#  Row(request_address='WURZBACH RD and WB IH 10'),
#  Row(request_address='WURZBACH RD and TOURANT RD'),
#  Row(request_address='WURZBACH RD and TIMBERHILL DR'),
#  Row(request_address='WURZBACH RD and PARKDALE'),
#  Row(request_address='WURZBACH RD and MELROSE HLMGRN'),
#  Row(request_address='WURZBACH RD and FERN GLEN'),
#  Row(request_address='WURZBACH RD and EVERS RD'),
#  Row(request_address='WURZBACH RD and BLUEMEL'),
#  Row(request_address='WURZBACH PKWY and WURZBACH RD'),
#  Row(request_address='WURZBACH PKWY and TECH COM'),
#  Row(request_address='WREXHAM HEIGHT and QUEEN HEIGHTS'),
#  Row(request_address='WRANGLER WAY and WRANGLER VIEW'),
#  Row(request_address='WRANGLER RUN and WRANGLER WAY'),
#  Row(request_address='WOOLLCOTT and CRESTON'),
#  Row(request_address='WOOLLCOTT and CRESTON'),
#  Row(request_address='WOODWAY FOREST and WOOD VALLEY'),
#  Row(request_address='WOODWATERS WAY and WOODWAY PLACE'),
#  Row(request_address='WOODTRAIL and LANSBURY'),
#  Row(request_address='WOODTRAIL and LANSBURY'),
#  Row(request_address='WOODTRAIL and LANSBURY'),
#  Row(request_address='WOODTRAIL and LANSBURY'),
#  Row(request_address='WOODTRAIL and HARDESTY'),
#  Row(request_address='WOODSTONE and IH 10 W'),
#  Row(request_address='WOODSTONE WAY and FOUNTAINWOOD'),
#  Row(request_address='WOODSTONE WAY and FOUNTAINWOOD'),
#  Row(request_address='WOODSTONE WAY and FOUNTAINWOOD'),
#  Row(request_address='WOODSTONE WAY and FOUNTAINWOOD'),
#  Row(request_address='WOODS HOLE and WADDESDON BLUF'),
#  Row(request_address='WOODRIDGE HILL and WOODRIDGE ROCK'),
#  Row(request_address='WOODRIDGE COVE and WOODRDGE BLUFF'),
#  Row(request_address='WOODRIDGE COVE and WOODRDGE BLUFF'),
#  Row(request_address='WOODRIDGE COVE and WOODRDGE BLUFF'),
#  Row(request_address='WOODRIDGE COVE and WOODRDGE BLUFF'),
#  Row(request_address='WOODRIDGE COVE and WOODRDGE BLUFF'),
#  Row(request_address='WOODRIDGE COVE and WOODRDGE BLUFF'),
#  Row(request_address='WOODRIDGE COVE and SUNSET CREST'),
#  Row(request_address='WOODRDG FOREST and WOODRIDGE HILL'),
#  Row(request_address='WOODRDG FOREST and WOODRIDGE HILL'),
#  Row(request_address='WOODRDG FOREST and WOODRIDGE HILL'),
#  Row(request_address='WOODRDG FOREST and WOODRIDGE HILL'),
#  Row(request_address='WOODMOOR DR and AUTUMN VISTA'),
#  Row(request_address='WOODMANOR DR and SUTTON'),
#  Row(request_address='WOODMANOR DR and SUTTON'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and ZARZAMORA N'),
#  Row(request_address='WOODLAWN W and WILSON BLVD'),
#  Row(request_address='WOODLAWN W and WILSON BLVD'),
#  Row(request_address='WOODLAWN W and ST CLOUD RD'),
#  Row(request_address='WOODLAWN W and RIPLEY AVE'),
#  Row(request_address='WOODLAWN W and LAKE BLVD'),
#  Row(request_address='WOODLAWN W and JOSE TOBIN N'),
#  Row(request_address='WOODLAWN W and DUKE AVE'),
#  Row(request_address='WOODLAWN W and CAMINO SANTA M'),
#  Row(request_address='WOODLAWN W and CAMINO SANTA M'),
#  Row(request_address='WOODLAWN W and CALAVERAS N'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN W and 36TH ST NW'),
#  Row(request_address='WOODLAWN ENT and EB IH 10'),
#  Row(request_address='WOODLAWN ENT and EB IH 10'),
#  Row(request_address='WOODLAWN ENT and EB IH 10'),
#  Row(request_address='WOODLAWN E and ST MARYS N'),
#  Row(request_address='WOODLAWN E and MCCULLOUGH AVE'),
#  Row(request_address='WOODLAWN E and CARLETON'),
#  Row(request_address='WOODLAWN E and CARLETON'),
#  Row(request_address='WOODLAWN E and CARLETON'),
#  Row(request_address='WOODLAND PINES and APRICOT BLOOM'),
#  Row(request_address='WOODLAND HILLS and FOREST VILLAGE'),
#  Row(request_address='WOODLAKE POINT and WOODLAKE VIEW'),
#  Row(request_address='WOODLAKE PKWY and GOLF VISTA BV'),
#  Row(request_address='WOODLAKE PKWY and GIBBS SPRAWL'),
#  Row(request_address='WOODLAKE PKWY and GIBBS SPRAWL'),
#  Row(request_address='WOODLAKE PKWY and GIBBS SPRAWL'),
#  Row(request_address='WOODLAKE PKWY and GIBBS SPRAWL'),
#  Row(request_address='WOODLAKE PKWY and GIBBS SPRAWL'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODLAKE CNTER and RAILWAY'),
#  Row(request_address='WOODHILL and STONESHIRE'),
#  Row(request_address='WOODHILL and STONESHIRE'),
#  Row(request_address='WOODHILL and STONESHIRE'),
#  Row(request_address='WOODHEATHER and WICKERSHAM'),
#  Row(request_address='WOODGREEN and STONESHIRE'),
#  Row(request_address='WOODGREEN and STONESHIRE'),
#  Row(request_address='WOODCREST DR and NEW BRNFLS N'),
#  Row(request_address='WOODCHASE and ECKHERT RD'),
#  Row(request_address='WOODCHASE and ECKHERT RD'),
#  Row(request_address='WOODBURY DR and FLOURISANT'),
#  Row(request_address='WOODBURY DR and FLOURISANT'),
#  Row(request_address='WOODBROOK and WOODHILL'),
#  Row(request_address='WOODBROOK and WOODHILL'),
#  Row(request_address='WOODBROOK and WOODHILL'),
#  Row(request_address='WOODBROOK and WOODGREEN'),
#  Row(request_address='WOODBROOK and WOODGREEN'),
#  Row(request_address='WOODBROOK and WOODGREEN'),
#  Row(request_address='WOODBROOK and WOODGREEN'),
#  Row(request_address='WOODBROOK and WOODGREEN'),
#  Row(request_address='WOODBROOK and WOODGREEN'),
#  Row(request_address='WOODBROOK and WOODGREEN'),
#  Row(request_address='WOODBROOK and THORNWOOD'),
#  Row(request_address='WOODBROOK and THORNWOOD'),
#  Row(request_address='WOOD WIND and VILLAGE PKWY'),
#  Row(request_address='WOOD SORREL and DESERT POPPY'),
#  Row(request_address='WOOD SORREL and DESERT POPPY'),
#  Row(request_address='WOOD SHADOW and WOOD VALLEY'),
#  Row(request_address='WOOD POINT and WILDERNESS WD'),
#  Row(request_address='WOOD OAK and WOOD CLIMB DR'),
#  Row(request_address='WOOD OAK and FOUNTAINWOOD'),
#  Row(request_address='WOOD HARBOR and WOOD PASS'),
#  Row(request_address='WOOD HARBOR and WOOD PASS'),
#  Row(request_address='WOOD FOREST and VILLAGE PKWY'),
#  Row(request_address='WOOD BREEZE and BOHILL'),
#  Row(request_address='WOOD BREEZE and BOHILL'),
#  Row(request_address='WOOD BOW and WOOD CIRCLE'),
#  Row(request_address='WOOD BOW and WOOD CIRCLE'),
#  Row(request_address='WOOD BOW and WOOD CIRCLE'),
#  Row(request_address='WOOD BAYOU and WOODWATERS WAY'),
#  Row(request_address='WOOD ARBOR and WOOD CIRCLE'),
#  Row(request_address='WOOD ARBOR and WOOD CIRCLE'),
#  Row(request_address='WOOD ARBOR and WOOD CIRCLE'),
#  Row(request_address='WOOD ARBOR and WOOD CIRCLE'),
#  Row(request_address='WONDER PKWY and MACE'),
#  Row(request_address='WONDER PKWY and FREILING DR'),
#  Row(request_address='WOLLER RD and BEAVER TREE'),
#  Row(request_address='WOLLER PATH and WOLLER TRAIL'),
#  Row(request_address='WOLLER PATH and WOLLER TRAIL'),
#  Row(request_address='WOLLER PATH and WOLLER PLACE'),
#  Row(request_address='WOLLER PATH and WOLLER PLACE'),
#  Row(request_address='WOLF POINT and REBECCAS TRAIL'),
#  Row(request_address='WOLF POINT and REBECCAS TRAIL'),
#  Row(request_address='WOLF POINT and DILLONS VISTA'),
#  Row(request_address='WOLF CREEK and ROTHBURY'),
#  Row(request_address='WISTERIA WAY and LIATRIS LANE'),
#  Row(request_address='WISTERIA WAY and LIATRIS LANE'),
#  Row(request_address='WISTERIA HILL and WOODLAKE PKWY'),
#  Row(request_address='WISTERIA HILL and WOODLAKE PKWY'),
#  Row(request_address='WISTERIA HILL and WOODLAKE PKWY'),
#  Row(request_address='WISTERIA HILL and WOODLAKE PKWY'),
#  Row(request_address='WISTERIA HILL and WOODLAKE PKWY'),
#  Row(request_address='WISTERIA HILL and WOODLAKE PKWY'),
#  Row(request_address='WISTERIA HILL and WOODLAKE PKWY'),
#  Row(request_address='WISTERIA HILL and WOODLAKE PKWY'),
#  Row(request_address='WISEMAN BLVD and STATE HWY 151'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and ROGERS RD'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WISEMAN BLVD and IMPALA SUMMIT'),
#  Row(request_address='WINTHOP and SYRACUSE'),
#  Row(request_address='WINSFORD DR and OLDHAM DR'),
#  Row(request_address='WINSFORD DR and CUL-DE-SAC'),
#  Row(request_address='WINSFORD DR and CUL-DE-SAC'),
#  Row(request_address='WINSFORD DR and BRIDLEWAY DR'),
#  Row(request_address='WINNIPEG AVE W and ZARZAMORA S'),
#  Row(request_address='WINNIPEG AVE W and ZARZAMORA S'),
#  Row(request_address='WINNIPEG AVE W and S ZARZAMORA'),
#  Row(request_address='WINNIPEG AVE W and S ZARZAMORA'),
#  Row(request_address='WINNIPEG AVE W and S ZARZAMORA'),
#  Row(request_address='WINNIPEG AVE W and S ZARZAMORA'),
#  Row(request_address='WINNIPEG AVE W and COLLINGSWORTH'),
#  Row(request_address='WINNIPEG AVE W and CHARLOTTE ST'),
#  Row(request_address='WINNIPEG AVE W and CHARLOTTE ST'),
#  Row(request_address='WINNEWAY and CRATER DR'),
#  Row(request_address='WINNEWAY and BERMUDA'),
#  Row(request_address='WINKLE COURT and ORR DR'),
#  Row(request_address='WINDYHILL and ROYALGATE DR'),
#  Row(request_address='WINDWAY DR and WALZEM RD'),
#  Row(request_address='WINDWAY DR and WALZEM RD'),
#  Row(request_address='WINDWAY DR and WALZEM RD'),
#  Row(request_address='WINDWAY DR and WALZEM RD'),
#  Row(request_address='WINDWAY DR and WALZEM RD'),
#  Row(request_address='WINDWAY DR and WALZEM RD'),
#  Row(request_address='WINDWAY DR and WALZEM RD'),
#  Row(request_address='WINDSOR HOLLOW and WINDSOR OAKS'),
#  Row(request_address='WINDSOR HOLLOW and WINDSOR OAKS'),
#  Row(request_address='WINDSOR DR and MORNING GLORY'),
#  Row(request_address='WINDSOR CASTLE and CUL-DE-SAC'),
#  Row(request_address='WINDSOR CASTLE and CUL-DE-SAC'),
#  Row(request_address='WINDSOR CASTLE and CUL-DE-SAC'),
#  Row(request_address='WINDSOR CASTLE and CUL-DE-SAC'),
#  Row(request_address='WINDSOR CASTLE and CUL-DE-SAC'),
#  Row(request_address='WINDSOR CASTLE and CUL-DE-SAC'),
#  Row(request_address='WINDSOR CASTLE and CUL-DE-SAC'),
#  Row(request_address='WINDSOR CASTLE and CUL-DE-SAC'),
#  Row(request_address='WINDLINE and WOODLINE'),
#  Row(request_address='WINDLINE and WOODLINE'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and WOODCLIFFE DR'),
#  Row(request_address='WINDLAKE DR and TAWNY OAK'),
#  Row(request_address='WINDING FARM and BROCKTHORN DR'),
#  Row(request_address='WINDING ELM PL and SANDBROOK HILL'),
#  Row(request_address='WINDGAP and BULL RUN'),
#  Row(request_address='WINDGAP and BULL RUN'),
#  Row(request_address='WINDBROOKE DR and AUTUMN VISTA'),
#  Row(request_address='WINDBROOKE DR and AUTUMN VISTA'),
#  Row(request_address='WINDBROOKE DR and AUTUMN VISTA'),
#  Row(request_address='WINDBROOKE DR and AUTUMN VISTA'),
#  Row(request_address='WINDBROOKE DR and AUTUMN VISTA'),
#  Row(request_address='WINDBROOKE DR and AUTUMN VISTA'),
#  Row(request_address='WINDBRIDGE and TRAWOOD'),
#  Row(request_address='WIND DANCER and WIND TALKER'),
#  Row(request_address='WIND CAVE and ARIZONA ASH'),
#  Row(request_address='WINCHEAP FARM and ABSOLON FARM'),
#  Row(request_address='WINCHEAP FARM and ABSOLON FARM'),
#  Row(request_address='WINCHEAP FARM and ABSOLON FARM'),
#  Row(request_address='WINCHEAP FARM and ABSOLON FARM'),
#  Row(request_address='WINCHEAP FARM and ABSOLON FARM'),
#  Row(request_address='WIMBERLY BLVD and YETT AVE'),
#  Row(request_address='WIMBERLY BLVD and YETT AVE'),
#  Row(request_address='WIMBERLY BLVD and YETT AVE'),
#  Row(request_address='WIMBERLY BLVD and WALHALLA AVE'),
#  Row(request_address='WILSON CREEK and PORT HUDSON'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and WOODLAWN W'),
#  Row(request_address='WILSON BLVD and OVERDALE'),
#  Row(request_address='WILSON BLVD and HAVERHILL DR'),
#  Row(request_address='WILSON BLVD and CROMWELL'),
#  Row(request_address='WILMINGTON AVE and EUCLID AVE E'),
#  Row(request_address='WILMINGTON AVE and EUCLID AVE E'),
#  Row(request_address='WILMINGTON AVE and EUCLID AVE E'),
#  Row(request_address='WILMINGTON AVE and EUCLID AVE E'),
#  Row(request_address='WILMA JEAN DR and PETALUMA BV W'),
#  Row(request_address='WILMA JEAN DR and PETALUMA BV W'),
#  Row(request_address='WILMA JEAN DR and PETALUMA BV W'),
#  Row(request_address='WILMA JEAN DR and PETALUMA BV W'),
#  Row(request_address='WILMA JEAN DR and PETALUMA BV W'),
#  Row(request_address='WILMA JEAN DR and PETALUMA BV W'),
#  Row(request_address='WILLOWWOOD BV and VERDUM DR'),
#  Row(request_address='WILLOWWOOD BV and BELGIUM'),
#  Row(request_address='WILLOWRIDGE LN and AUTUMN VISTA'),
#  Row(request_address='WILLOWKNOLL CV and SAVANNAH PASS'),
#  Row(request_address='WILLOWBROOK DR and LOOKOUT DR'),
#  Row(request_address='WILLOWBROOK DR and LOOKOUT DR'),
#  Row(request_address='WILLOWBROOK DR and LOOKOUT DR'),
#  Row(request_address='WILLOWBLUFF DR and WOOD VALLEY'),
#  Row(request_address='WILLOWBLUFF DR and WOOD VALLEY'),
#  Row(request_address='WILLOWBLUFF DR and WOOD VALLEY'),
#  Row(request_address='WILLOW TRAIL and WILLOW BEND'),
#  Row(request_address='WILLOW RUN and PONY CHASE'),
#  Row(request_address='WILLOW RUN and PONY CHASE'),
#  Row(request_address='WILLOW RUN and MARTINS FERRY'),
#  Row(request_address='WILLOW OAK and RIDGE OAK PKWY'),
#  Row(request_address='WILLOW OAK and RIDGE OAK PKWY'),
#  Row(request_address='WILLOW OAK and RIDGE OAK PKWY'),
#  Row(request_address='WILLOW OAK and RIDGE OAK PKWY'),
#  Row(request_address='WILLOW HILL and WILLOW RUN'),
#  Row(request_address='WILLOW HILL and WILLOW RUN'),
#  Row(request_address='WILLOW GROVE and IMPALA SPRINGS'),
#  Row(request_address='WILLOW GROVE and IMPALA SPRINGS'),
#  Row(request_address='WILLOW GROVE and IMPALA SPRINGS'),
#  Row(request_address='WILLOW GROVE and BRIDLE VIEW DR'),
#  Row(request_address='WILLOW BEND and WILLOW TRAIL'),
#  Row(request_address='WILLIS RANCH and BULVERDE RD'),
#  Row(request_address='WILLIAMSBURG and OZARK'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLIAM PENN and LITCHFIELD'),
#  Row(request_address='WILLENBROCK and WYCLIFF'),
#  Row(request_address='WILLENBROCK and WYCLIFF'),
#  Row(request_address='WILLEE and 38TH ST NW'),
#  Row(request_address='WILLEE and 38TH ST NW'),
#  Row(request_address='WILLEE and 38TH ST NW'),
#  Row(request_address='WILLEE and 38TH ST NW'),
#  Row(request_address='WILLARD PATH and MARLARK PASS'),
#  Row(request_address='WILLARD DR and BANDERA RD'),
#  Row(request_address='WILLARD DR and BANDERA RD'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILLARD DR and 36TH ST NW'),
#  Row(request_address='WILDWOOD W and MICHIGAN AVE'),
#  Row(request_address='WILDWOOD W and MELBOURNE ST'),
#  Row(request_address='WILDWOOD W and MELBOURNE ST'),
#  Row(request_address='WILDWOOD W and BREEDEN ST'),
#  Row(request_address='WILDWOOD W and BEACON AVE'),
#  Row(request_address='WILDWOOD RIDGE and WOODLAND HILLS'),
#  Row(request_address='WILDT RD and BONAIR'),
#  Row(request_address='WILDSTONE CI and CUL-DE-SAC'),
#  Row(request_address='WILDHORSE PKWY and BUCKSKIN BEND'),
#  Row(request_address='WILDFLOWER WAY and SUNSET BEND'),
#  Row(request_address='WILDFLOWER TRL and FERNBROOK'),
#  Row(request_address='WILDERNESS WD and WILDERNESS PT'),
#  Row(request_address='WILDERNESS PT and GEORGE RD'),
#  Row(request_address='WILDERNESS PT and GEORGE RD'),
#  Row(request_address='WILDERNESS OAK and SPENCER GATE'),
#  Row(request_address='WILDERNESS OAK and SPENCER GATE'),
#  Row(request_address='WILDERNESS OAK and BULVERDE RD'),
#  Row(request_address='WILDER and LAMERTON'),
#  Row(request_address='WILDER and LAMERTON'),
#  Row(request_address='WILDER and LAMERTON'),
#  Row(request_address='WILDER and DOVER RIDGE'),
#  Row(request_address='WILDER and DOVER RIDGE'),
#  Row(request_address='WILDER and DOVER RIDGE'),
#  Row(request_address='WILDE GLEN and SCOTS GLEN'),
#  Row(request_address='WILD TURKEY E and TURKEY POINT'),
#  Row(request_address='WILD TRAILS and VALLEY TRAILS'),
#  Row(request_address='WILD TRAILS and VALLEY TRAILS'),
#  Row(request_address='WILD TRAILS and VALLEY TRAILS'),
#  Row(request_address='WILD OAK DR and YELLOW WOOD'),
#  Row(request_address='WILD OAK DR and YELLOW WOOD'),
#  Row(request_address='WILD OAK DR and YELLOW WOOD'),
#  Row(request_address='WILD OAK DR and MANHATTAN'),
#  Row(request_address='WILD ISLAND and WIND DANCER'),
#  Row(request_address='WILD ISLAND and WIND DANCER'),
#  Row(request_address='WILD FIRE and WIND DANCER'),
#  Row(request_address='WILD FIRE and WIND DANCER'),
#  Row(request_address='WILCOX and CREIGHTON AVE'),
#  Row(request_address='WILCHESTER and SOUTHWOOD LANE'),
#  Row(request_address='WIKIEUP ST and REFORMA DR'),
#  Row(request_address='WICKERSHAM and WICKHEATHER'),
#  Row(request_address='WICKERSHAM and WICKHEATHER'),
#  Row(request_address='WICKERSHAM and LORNA DOONE'),
#  Row(request_address='WICKERSHAM and LORNA DOONE'),
#  Row(request_address='WICKERSHAM and HERALDRY'),
#  Row(request_address='WICKERSHAM and GUILBEAU RD'),
#  Row(request_address='WICKERSHAM and GUILBEAU RD'),
#  Row(request_address='WICKERSHAM and GUILBEAU RD'),
#  Row(request_address='WHITTIER ST E and YORKSHIRE PL'),
#  Row(request_address='WHITTIER ST E and YORKSHIRE PL'),
#  Row(request_address='WHITTIER ST E and YORKSHIRE PL'),
#  Row(request_address='WHITTIER ST E and YORKSHIRE PL'),
#  Row(request_address='WHITTIER ST E and YORKSHIRE PL'),
#  Row(request_address='WHITTIER ST E and YORKSHIRE PL'),
#  Row(request_address='WHITTIER ST E and ROSEBOROUGH ST'),
#  Row(request_address='WHITNEYS COURT and CUL-DE-SAC'),
#  Row(request_address='WHITMAN AVE and ZARZAMORA S'),
#  Row(request_address='WHITMAN AVE and ZARZAMORA S'),
#  Row(request_address='WHITMAN AVE and S ZARZAMORA'),
#  Row(request_address='WHITMAN AVE and S ZARZAMORA'),
#  Row(request_address='WHITMAN AVE and LENARD'),
#  Row(request_address='WHITMAN AVE and LENARD'),
#  Row(request_address='WHITMAN AVE and LENARD'),
#  Row(request_address='WHITING and EADS AVE'),
#  Row(request_address='WHITING and EADS AVE'),
#  Row(request_address='WHITING and EADS AVE'),
#  Row(request_address='WHITING and EADS AVE'),
#  Row(request_address='WHITING and EADS AVE'),
#  Row(request_address='WHITEWOOD DR and KNOLL KREST DR'),
#  Row(request_address='WHITEWOOD DR and KNOLL KREST DR'),
#  Row(request_address='WHITEWOOD DR and KNOLL KREST DR'),
#  Row(request_address='WHITEHALL and CORONET'),
#  Row(request_address='WHITE ROCK DR and HARVEST TIME'),
#  Row(request_address='WHITE OAK and WOODCLIFFE DR'),
#  Row(request_address='WHITE OAK and WOODCLIFFE DR'),
#  Row(request_address='WHITE OAK and WOODCLIFFE DR'),
#  Row(request_address='WHITE OAK and WOODCLIFFE DR'),
#  Row(request_address='WHITE OAK and SHADY SPRINGS'),
#  Row(request_address='WHITE CLOUD and CAMINO REAL'),
#  Row(request_address='WHITE AVE W and SEDALIA'),
#  Row(request_address='WHITBY RD and HUEBNER RD'),
#  Row(request_address='WHITBY RD and HUEBNER RD'),
#  Row(request_address='WHISPERING LAK and VISTA LAKE'),
#  Row(request_address='WHISPERING LAK and VISTA LAKE'),
#  Row(request_address='WHISPERING CRK and SUSANWOOD'),
#  Row(request_address='WHISPERING CRK and SUSANWOOD'),
#  Row(request_address='WHISPERING CRK and SUSANWOOD'),
#  Row(request_address='WHISPERING CRK and SUSANWOOD'),
#  Row(request_address='WHISPER WOOD and WOOD VALLEY'),
#  Row(request_address='WHISPER WOOD and CUL-DE-SAC'),
#  Row(request_address='WHISPER WILLOW and WURZBACH RD'),
#  Row(request_address='WHISPER WILLOW and WURZBACH RD'),
#  Row(request_address='WHISPER VIEW and WHISPER PATH'),
#  Row(request_address='WHISPER VALLEY and WURZBACH RD'),
#  Row(request_address='WHISPER VALLEY and WURZBACH RD'),
#  Row(request_address='WHISPER VALLEY and WURZBACH RD'),
#  Row(request_address='WHISPER VALLEY and WURZBACH RD'),
#  Row(request_address='WHISPER VALLEY and WURZBACH RD'),
#  Row(request_address='WHISPER VALLEY and WINDY OAKS'),
#  Row(request_address='WHISPER VALLEY and WHISPERNG WIND'),
#  Row(request_address='WHISPER VALLEY and WHISPERNG WIND'),
#  Row(request_address='WHISPER VALLEY and WHISPER VIEW'),
#  Row(request_address='WHISPER VALLEY and WHISPER VIEW'),
#  Row(request_address='WHISPER VALLEY and WHISPER PATH'),
#  Row(request_address='WHISPER TRAIL and WHISPER WILLOW'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER SOUND and WURZBACH RD'),
#  Row(request_address='WHISPER RIDGE and WHISPER VALLEY'),
#  Row(request_address='WHISPER PATH and WHISPER VALLEY'),
#  Row(request_address='WHISPER PATH and WHISPER VALLEY'),
#  Row(request_address='WHISPER MOSS and WHISPER VALLEY'),
#  Row(request_address='WHISPER MOSS and WHISPER VALLEY'),
#  Row(request_address='WHISPER MOSS and WHISPER VALLEY'),
#  Row(request_address='WHISPER MOSS and WHISPER VALLEY'),
#  Row(request_address='WHISPER MEADOW and WHISPER FERN'),
#  Row(request_address='WHISPER HOLLOW and WHISPER VALLEY'),
#  Row(request_address='WHISPER GREEN and WHISPER WILLOW'),
#  Row(request_address='WHISPER GREEN and WHISPER WILLOW'),
#  Row(request_address='WHISPER GLEN and WHISPER WILLOW'),
#  Row(request_address='WHISPER FERN and WHISPER MEADOW'),
#  Row(request_address='WHISPER FAWN and WHISPER VALLEY'),
#  Row(request_address='WHISPER FAWN and WHISPER VALLEY'),
#  Row(request_address='WHISPER FAWN and WHISPER VALLEY'),
#  Row(request_address='WHISPER FAWN and WHISPER SLOE'),
#  Row(request_address='WHISPER FALLS and WHISPER WILLOW'),
#  Row(request_address='WHISPER DEW DR and WHISPER WILLOW'),
#  Row(request_address='WHISPER DAWN and WHISPER WILLOW'),
#  Row(request_address='WHISPER BREEZE and WHISPER WILLOW'),
#  Row(request_address='WHISPER BREEZE and WHISPER WILLOW'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHISPER BOW and WURZBACH RD'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHEATLEY AVE and YUCCA ST'),
#  Row(request_address='WHARTON ST and WHITING'),
#  Row(request_address='WHARTON ST and WHITING'),
#  Row(request_address='WHARTON ST and WHITING'),
#  Row(request_address='WHARTON ST and WHITING'),
#  Row(request_address='WHARTON ST and WHITING'),
#  Row(request_address='WHARTON ST and WHITING'),
#  Row(request_address='WHARTON ST and WHITING'),
#  Row(request_address='WHARTON ST and WHITING'),
#  Row(request_address='WEYBRIDGE and WOODTRAIL'),
#  Row(request_address='WEYBRIDGE and WOODTRAIL'),
#  Row(request_address='WEYBRIDGE and WOODTRAIL'),
#  Row(request_address='WEYBRIDGE and WOODTRAIL'),
#  Row(request_address='WEYBRIDGE and FERNVIEW'),
#  Row(request_address='WEYBRIDGE and FERNVIEW'),
#  Row(request_address='WEYBRIDGE and FERNVIEW'),
#  Row(request_address='WEYBRIDGE and FERNVIEW'),
#  Row(request_address='WEYBRIDGE and FERNVIEW'),
#  Row(request_address='WEYBRIDGE and FERNVIEW'),
#  Row(request_address='WEXFORD BROOK and WEXFORD RIDGE'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and WURZBACH PKWY'),
#  Row(request_address='WETMORE RD and STARCREST DR'),
#  Row(request_address='WETMORE RD and BROADWAY'),
#  Row(request_address='WESTWOOD and SAN PEDRO AVE'),
#  Row(request_address='WESTWOOD and BREEDEN ST'),
#  Row(request_address='WESTWOOD WAY and STONELEIGH WAY'),
#  Row(request_address='WESTWOOD LOOP and WILD PINE'),
#  Row(request_address='WESTWOOD LOOP and WESTWOOD VISTA'),
#  Row(request_address='WESTWOOD LOOP and WESTWOOD VISTA'),
#  Row(request_address='WESTWOOD LOOP and W 1604 N'),
#  Row(request_address='WESTWOOD LOOP and W 1604 N'),
#  Row(request_address='WESTWOOD LOOP and W 1604 N'),
#  Row(request_address='WESTWOOD LOOP and CULEBRA RD'),
#  Row(request_address='WESTWARD DR and WESTFIELD'),
#  Row(request_address='WESTWARD DR and MILITARY DR W'),
#  Row(request_address='WESTVILLE DR and RAWHIDE LANE'),
#  Row(request_address='WESTVALE and WESTVILLE DR'),
#  Row(request_address='WESTSHIRE DR and WESTVALE'),
#  Row(request_address='WESTSHIRE DR and WESTVALE'),
#  Row(request_address='WESTSHIRE DR and WESTVALE'),
#  Row(request_address='WESTSHIRE DR and WESTVALE'),
#  Row(request_address='WESTSHIRE DR and CAMPFIRE LANE'),
#  Row(request_address='WESTROCK DR and WESTWARD DR'),
#  Row(request_address='WESTROCK DR and WESTWARD DR'),
#  Row(request_address='WESTOVER VIEW and CROSS SPRING'),
#  Row(request_address='WESTOVER VIEW and CROSS SPRING'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and WISEMAN BLVD'),
#  Row(request_address='WESTOVER HILLS and RABA DR'),
#  Row(request_address='WESTOVER HILLS and PORTOLA BLVD'),
#  Row(request_address='WESTOVER HILLS and CULEBRA RD'),
#  Row(request_address='WESTOAK RD and WESTROCK DR'),
#  Row(request_address='WESTOAK RD and WESTROCK DR'),
#  Row(request_address='WESTOAK RD and WESTROCK DR'),
#  Row(request_address='WESTOAK RD and WESTROCK DR'),
#  Row(request_address='WESTOAK RD and WESTFIELD'),
#  Row(request_address='WESTOAK RD and WB NEW HY 90 W'),
#  Row(request_address='WESTMOOR and WESTBRIAR'),
#  Row(request_address='WESTMONT and WESTOAK RD'),
#  Row(request_address='WESTMONT and WESTOAK RD'),
#  Row(request_address='WESTMONT and WESTOAK RD'),
#  Row(request_address='WESTMONT and WESTOAK RD'),
#  Row(request_address='WESTMONT and WESTOAK RD'),
#  Row(request_address='WESTMONT and WESTOAK RD'),
#  Row(request_address='WESTMINSTER and PURDUE'),
#  Row(request_address='WESTMAR and WESTVILLE DR'),
#  Row(request_address='WESTMAR and WESTVILLE DR'),
#  Row(request_address='WESTMAR and WESTVILLE DR'),
#  Row(request_address='WESTMAR and WESTVILLE DR'),
#  Row(request_address='WESTMAR and WESTPORT WAY'),
#  Row(request_address='WESTLYN and WESTVALE'),
#  Row(request_address='WESTLYN and WESTMOOR'),
#  Row(request_address='WESTLYN and WESTMOOR'),
#  Row(request_address='WESTLYN and WESTMAR'),
#  Row(request_address='WESTLYN and HACKAMORE LANE'),
#  Row(request_address='WESTLYN and HACKAMORE LANE'),
#  Row(request_address='WESTLAWN and WESTVALLEY'),
#  Row(request_address='WESTLAWN and WESTVALLEY'),
#  Row(request_address='WESTLAWN and WESTVALLEY'),
#  Row(request_address='WESTLAWN and WESTPLAIN'),
#  Row(request_address='WESTLAWN and WESTMAR'),
#  Row(request_address='WESTLAKE and WESTVALE'),
#  Row(request_address='WESTLAKE and WESTOAK RD'),
#  Row(request_address='WESTLAKE and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTKNOLL and WESTOAK RD'),
#  Row(request_address='WESTHILL and WILLIAMSBURG'),
#  Row(request_address='WESTHILL and WILLIAMSBURG'),
#  Row(request_address='WESTHAVEN and WESTOAK RD'),
#  Row(request_address='WESTHAVEN and WESTOAK RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and WHITBY RD'),
#  Row(request_address='WESTGROVE and BERRYWEST DR'),
#  Row(request_address='WESTFIELD and WESTWARD DR'),
#  Row(request_address='WESTFIELD and WESTWARD DR'),
#  Row(request_address='WESTFIELD and WESTWARD DR'),
#  Row(request_address='WESTFIELD and WESTWARD DR'),
#  Row(request_address='WESTFIELD and WESTWARD DR'),
#  Row(request_address='WESTFIELD and WESTVALE'),
#  Row(request_address='WESTFIELD and WESTVALE'),
#  Row(request_address='WESTFIELD and WESTVALE'),
#  Row(request_address='WESTFIELD and WESTVALE'),
#  Row(request_address='WESTFIELD and WESTVALE'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and WESTOAK RD'),
#  Row(request_address='WESTFIELD and RAWHIDE LANE'),
#  Row(request_address='WESTFIELD and MILITARY DR W'),
#  Row(request_address='WESTFALL AVE and WALTERS S'),
#  Row(request_address='WESTFALL AVE and ST ANTHONY AV'),
#  Row(request_address='WESTERNHILL DR and WESTOVER WAY'),
#  Row(request_address='WESTERNHILL DR and WESTOVER WAY'),
#  Row(request_address='WESTERN SKIES and WESTERN SUN'),
#  Row(request_address='WESTERN CROSS and ROGERS RD'),
#  Row(request_address='WESTERN CROSS and ROGERS RD'),
#  Row(request_address='WESTERN CROSS and ROGERS RD'),
#  Row(request_address='WESTERN CROSS and ROGERS RD'),
#  Row(request_address='WESTERN CROSS and ROGERS RD'),
#  ...]

# %% [markdown]
# 9. What are the top 10 service request types in terms of number of requests?

# %%
df.groupBy(df.service_request_type).agg(count(df.service_request_type)).sort("count(service_request_type)", ascending=False).show(10)
# Out:
# [Stage 250:=======>                                                 (1 + 7) / 8]
# +--------------------+---------------------------+
# |service_request_type|count(service_request_type)|
# +--------------------+---------------------------+
# |           No Pickup|                      89210|
# |Overgrown Yard/Trash|                      66403|
# |        Bandit Signs|                      32968|
# |        Damaged Cart|                      31163|
# |Front Or Side Yar...|                      28920|
# |        Stray Animal|                      27361|
# |Aggressive Animal...|                      25492|
# |Cart Exchange Req...|                      22608|
# |Junk Vehicle On P...|                      21649|
# |     Pot Hole Repair|                      20827|
# +--------------------+---------------------------+
# only showing top 10 rows

# %% [markdown]
# 10. What are the top 10 service request types in terms of average days late?

# %%
df.groupBy(df.service_request_type).agg(mean(df.num_days_late), count(df.num_days_late)).sort("avg(num_days_late)", ascending=False).show(10)
# Out:
# [Stage 410:>                                                        (0 + 8) / 8]
# +--------------------+------------------+--------------------+
# |service_request_type|avg(num_days_late)|count(num_days_late)|
# +--------------------+------------------+--------------------+
# |  Zoning: Junk Yards|175.95636210420932|                 296|
# |Labeling for Used...|162.43032902285717|                   7|
# |Record Keeping of...|153.99724039428568|                   7|
# |Signage Requied f...|151.63868055333333|                  12|
# |Storage of Used M...|142.11255641500003|                   8|
# |Zoning: Recycle Yard| 135.9285161247979|                 198|
# |Donation Containe...|131.75610506358709|                 155|
# |License Requied U...|128.79828704142858|                   7|
# |Traffic Signal Gr...|101.79846062200002|                   5|
# |           Complaint| 72.87050230311698|                2420|
# +--------------------+------------------+--------------------+
# only showing top 10 rows

# %% [markdown]
# 11. Does number of days late depend on department? Yes

# %%
df.groupBy(df.standardized_dept_name).agg(count(df.num_days_late), mean(df.num_days_late)).sort("avg(num_days_late)", ascending=False).show(10)
# Out:
# +----------------------+--------------------+-------------------+
# |standardized_dept_name|count(num_days_late)| avg(num_days_late)|
# +----------------------+--------------------+-------------------+
# |      Customer Service|                2889|  59.73709149630082|
# |           Solid Waste|              286287|-2.2000575136721685|
# |          Metro Health|                5313| -4.911766979607001|
# |    Parks & Recreation|               19964| -5.251521960055156|
# |  Trans & Cap Impro...|               97841|-20.612837354052726|
# |  DSD/Code Enforcement|              323579| -38.36938892614369|
# |  Animal Care Services|              119362| -226.5178394055035|
# |          City Council|                   0|               null|
# +----------------------+--------------------+-------------------+

# %% [markdown]
# 12. How do number of days late depend on department and request type? certain deptarments and requests can take longer

# %%
df.groupBy(df.standardized_dept_name, df.service_request_type).agg(mean(df.num_days_late)).sort("avg(num_days_late)", ascending=False).show(50)
# Out:
# [Stage 480:>                                                        (0 + 8) / 8]
# +----------------------+--------------------+------------------+
# |standardized_dept_name|service_request_type|avg(num_days_late)|
# +----------------------+--------------------+------------------+
# |  DSD/Code Enforcement|  Zoning: Junk Yards|175.95636210420932|
# |  DSD/Code Enforcement|Labeling for Used...|162.43032902285717|
# |  DSD/Code Enforcement|Record Keeping of...|153.99724039428568|
# |  DSD/Code Enforcement|Signage Requied f...|151.63868055333333|
# |  DSD/Code Enforcement|Storage of Used M...|142.11255641500003|
# |  DSD/Code Enforcement|Zoning: Recycle Yard| 135.9285161247979|
# |  DSD/Code Enforcement|Donation Containe...|131.75610506358709|
# |  DSD/Code Enforcement|License Requied U...|128.79828704142858|
# |  Trans & Cap Impro...|Traffic Signal Gr...|101.79846062200002|
# |      Customer Service|           Complaint| 72.87050230311696|
# |  DSD/Code Enforcement|             Vendors|   66.548098985078|
# |    Parks & Recreation|Reservation Assis...|       66.03116319|
# |  DSD/Code Enforcement|   No Address Posted| 59.87564073362592|
# |  DSD/Code Enforcement|         Curbstoning| 59.80862897760526|
# |           Solid Waste|Contracted Servic...|    56.72045236025|
# |  Trans & Cap Impro...|Status: On-Going ...| 37.57064670295011|
# |  DSD/Code Enforcement|Historical Buildi...|31.567148565454545|
# |  DSD/Code Enforcement|Used Mattress Ins...|30.168053900795922|
# |           Solid Waste| Service Information|29.177355749054886|
# |    Parks & Recreation|Park Building Mai...|24.322320840895838|
# |           Solid Waste|Solid Waste Fees ...| 22.43066553054067|
# |  DSD/Code Enforcement|Emergency: Main a...| 22.25381130062963|
# |  Animal Care Services|Animal Permits Re...|22.197922714476807|
# |    Parks & Recreation| Sportfield Lighting| 19.63121452995114|
# |  Trans & Cap Impro...|Markings Installa...|    16.81324652075|
# |  Animal Care Services|Aggressive Animal...|16.696368811892228|
# |           Solid Waste|Organics Info / L...|14.251441689631406|
# |  DSD/Code Enforcement|Street Light Exis...|13.664778521783164|
# |  DSD/Code Enforcement|Boarding Home Ins...|12.732003113287348|
# |    Parks & Recreation|          Electrical|11.750504897402134|
# |           Solid Waste|      Cart Placement| 10.44400618901405|
# |  Trans & Cap Impro...|Speed Hump Repair...|10.035641126898899|
# |    Parks & Recreation|Amenity Park Impr...| 9.641261768722687|
# |           Solid Waste|Disability Servic...| 9.107444643519093|
# |  DSD/Code Enforcement|Emergency: Access...|      8.8055057874|
# |  DSD/Code Enforcement|Emergency: Main S...| 8.342505786043478|
# |  DSD/Code Enforcement|Street Light New ...| 7.796007787581818|
# |  Animal Care Services|      Animal Neglect|  7.33292787806938|
# |    Parks & Recreation|        Tree Removal| 5.658236274288586|
# |           Solid Waste|      Alley Problems| 4.549660560465517|
# |    Parks & Recreation|            Painting|4.3544123582811425|
# |    Parks & Recreation|Tree Trimming/Mai...|  4.21017759706998|
# |    Parks & Recreation|General Building ...|4.1919455295795425|
# |    Parks & Recreation|             Masonry| 4.175698250885903|
# |    Parks & Recreation|    Sign Maintenance| 4.141523684634146|
# |           Solid Waste|Request for Comme...| 4.072424325988235|
# |           Solid Waste|Automation Proper...|3.7111600885405402|
# |    Parks & Recreation|   Fence/Gate Repair|3.6582782138442616|
# |           Solid Waste|Solid Waste - Mis...|3.5190239198762248|
# |  Animal Care Services|Aggressive Animal...| 2.645033883163266|
# +----------------------+--------------------+------------------+
# only showing top 50 rows
